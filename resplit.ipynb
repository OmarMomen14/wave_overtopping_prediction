# %%
import pandas as pd

# %%
df1 = pd.read_excel('training data filtered.xlsx', index_col=False)
df2 = pd.read_excel('testing data filtered.xlsx', index_col=False)

# %%
df1.shape
# Out:
# (4595, 36)

# %%
df2.shape
# Out:
# (1075, 36)

# %%
df = pd.concat([df1, df2], ignore_index=True, sort=False)

# %%
df.shape
# Out:
# (5670, 36)

# %%
df.iloc[4593:4599,:]
# Out:
#          Hm0 d      Tp d      Tm d   Tm1,0 d  hdeep     mmm  β  Spread s  \
# 4593  0.077667  1.196576  0.949663  1.146769   0.70  1000.0  0         0
# 4594  0.152000  1.652000  1.484000  1.571000   0.94    20.0  0         0
# 4595  0.155900  1.552000  1.343000  1.424000   0.94    20.0  0         0
# 4596  0.168000  1.621149  1.350958  1.473772   0.69  1000.0  0         0
# 4597  0.062000  1.251130  1.042609  1.137391   0.70    50.0  0         0
# 4598  0.193000  1.920000  1.600000  1.745455   1.40    52.0  0         0
#
#          h   Hm0 toe  ...     B     hb  tanαB    Bh     Ac     Gc  RF  CF  WF  \
# 4593  0.70  0.077667  ...  1.00  0.150    0.0  1.00  0.180  0.000   2   1   6
# 4594  0.37  0.128100  ...  0.50  0.040    0.0  0.50  0.170  0.310   2   1   6
# 4595  0.37  0.129600  ...  0.30  0.040    0.0  0.30  0.170  0.310   2   1   6
# 4596  0.69  0.168000  ...  0.00  0.000    0.0  0.00  0.075  0.178   2   1   6
# ...

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.iloc[4593:4599,:]
# Out:
#          Hm0 d      Tp d      Tm d   Tm1,0 d  hdeep     mmm  β  Spread s  \
# 4593  0.182000  2.160000  1.800000  1.963636   1.40    52.0  0         0
# 4594  0.121333  1.417175  1.180979  1.288341   0.61  1000.0  0         0
# 4595  0.137000  1.600000  1.360000  1.454545   0.59  1000.0  0         0
# 4596  0.118000  1.401010  1.167508  1.273645   0.61  1000.0  0         0
# 4597  0.157333  1.584219  1.320182  1.440199   0.61  1000.0  0         0
# 4598  0.121333  1.406398  1.171998  1.278544   0.61  1000.0  0         0
#
#          h   Hm0 toe  ...     B     hb  tanαB    Bh        Ac        Gc  RF  \
# 4593  0.40  0.182000  ...  0.15 -0.155    0.0  0.15  0.240000  0.000000   2
# 4594  0.61  0.121333  ...  0.00  0.000    0.0  0.00  0.100000  0.266667   1
# 4595  0.59  0.137000  ...  0.00  0.000    0.0  0.00  0.110000  0.180000   2
# 4596  0.61  0.118000  ...  0.00  0.000    0.0  0.00  0.066667  0.533333   1
# ...

# %%
df_train = df.iloc[:4595, :]
df_test = df.iloc[4595:, :]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4595 entries, 0 to 4594
# Data columns (total 36 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Hm0 d     4595 non-null   float64
#  1   Tp d      4595 non-null   float64
#  2   Tm d      4595 non-null   float64
#  3   Tm1,0 d   4595 non-null   float64
#  4   hdeep     4595 non-null   float64
#  5   mmm       4595 non-null   float64
#  6   β         4595 non-null   int64
#  7   Spread s  4595 non-null   int64
#  8   h         4595 non-null   float64
#  9   Hm0 toe   4595 non-null   float64
#  10  Tp toe    4595 non-null   float64
#  11  Tm toe    4595 non-null   float64
#  12  Tm1,0t    4595 non-null   float64
#  13  ht        4595 non-null   float64
#  14  Bt        4595 non-null   float64
#  15  cotαd     4595 non-null   float64
#  16  cotαu     4595 non-null   float64
#  17  cotαexcl  4595 non-null   float64
#  18  cotαincl  4595 non-null   float64
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1075 entries, 4595 to 5669
# Data columns (total 36 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Hm0 d     1075 non-null   float64
#  1   Tp d      1075 non-null   float64
#  2   Tm d      1075 non-null   float64
#  3   Tm1,0 d   1075 non-null   float64
#  4   hdeep     1075 non-null   float64
#  5   mmm       1075 non-null   float64
#  6   β         1075 non-null   int64
#  7   Spread s  1075 non-null   int64
#  8   h         1075 non-null   float64
#  9   Hm0 toe   1075 non-null   float64
#  10  Tp toe    1075 non-null   float64
#  11  Tm toe    1075 non-null   float64
#  12  Tm1,0t    1075 non-null   float64
#  13  ht        1075 non-null   float64
#  14  Bt        1075 non-null   float64
#  15  cotαd     1075 non-null   float64
#  16  cotαu     1075 non-null   float64
#  17  cotαexcl  1075 non-null   float64
#  18  cotαincl  1075 non-null   float64
# ...

# %%
df_train.to_excel('train_data2.xlsx', index=False)
df_test.to_excel('test_data2.xlsx', index=False)
